# %%
import numpy as np
import pandas as pd
from scipy.spatial import distance
from scipy.spatial import distance_matrix

# %%
def matprint(mat, fmt="g"):

    col_maxes = [max([len(("{:"+fmt+"}").format(x)) for x in col]) for col in mat.T]

    for x in mat:

        for i, y in enumerate(x):

            print(("{:"+str(col_maxes[i])+fmt+"}").format(y), end="  ")

        print("")

# %%
#messing around with auto generated closeness
import random
from time import time

points = (120, 150)
dims = (128, 128)

#pick between 1 and 10 points of interest
detections = random.randint(points[0], points[1])
print("Points:")
print(detections)
#pick random amount of rows
rows = random.randint(1,int(detections / 2))
#determine columns
print("Rows:")
print(rows)
cols = int(detections / rows)
if detections % rows != 0:
    cols = cols + 1
print("Cols:")
print(cols)
#determine indices
#random starting index somewhere in the bounds of the layer (left top)
start = (random.randint(1, dims[0] - rows), random.randint(1, dims[1] - cols))
print("Starting IDX:")
print(start)
idxs = []
for r in range(rows):
    for c in range(cols):
        if detections != 0:
            idxs.append((start[0] + r, start[1] + c))
        detections = detections - 1
        
# TODO: Copy stuff, more clumps.

# print("Indices:")
# print(idxs)
# print(len(idxs))

#testing how this would look in an array
arr = np.zeros((dims[0], dims[1]))
for idx in idxs:
    arr[idx[0], idx[1]] = 1
#print("Before Proximity")
#matprint(arr)

#now we need to fill initial proximity values
#euclidean distance. Each pixel is about 20x20 meters.
#to simplify calculations I think I'll just take the average coords of the 
#detections and calculate the distance from that...

centroid = [sum(idx) / len(idx) for idx in zip(*idxs)]

scale = 20 #meters per pixel
# Out:
# Points:
# 134
# Rows:
# 52
# Cols:
# 3
# Starting IDX:
# (39, 101)

# %%
#PROX
t0 = time()
#now fill in every point with the euclidean distance (scaled by 20)
for r in range(dims[0]):
    for c in range(dims[1]):
        if (r,c) not in idxs:
            min_dist = 10000
            for idx in idxs:
                temp = distance.euclidean((r,c), idx) * scale
                if temp < min_dist:
                    min_dist = temp
            arr[r, c] = min_dist
        else:
            arr[r, c] = 0
print(f"Time passed: {time() - t0}")
# print("Proximity")
matprint(arr)

# #CLOSENESS = 1/(1 + prox * alpha)
# alpha = .01
# new_im_array = arr.astype(float)
# new_im_array[~np.isnan(arr)] = \
#     1 / (1 + alpha * arr[~np.isnan(arr)])
# new_im_array[np.isnan(arr)] = np.nan
# new_im_array = np.round(new_im_array, 3)

# print("closeness")
# matprint(new_im_array)
# Out:
# Time passed: 37.95471811294556
# ...

# %%
def check_dist(feature, curr, quadrant, first):
    #check bounds
    if(curr[0] < 0 or curr[0] >= dims[0] or curr[1] < 0 or curr[1] >= dims[1]):
        return 1

    #find dist to curr from feature
    d = distance.euclidean(feature, curr)
    if d >= dists[curr] and not first:
        return 1
    dists[curr] = d
    arr1[curr[0]][curr[1]] = d * 20
    
    
    if quadrant == 1:
        check_dist(feature, (curr[0], curr[1] - 1), quadrant, False)
        check_dist(feature, (curr[0] + 1, curr[1]), quadrant, False)
    elif quadrant == 2:
        check_dist(feature, (curr[0], curr[1] - 1), quadrant, False)
        check_dist(feature, (curr[0] - 1, curr[1]), quadrant, False)
    elif quadrant == 3:
        check_dist(feature, (curr[0], curr[1] + 1), quadrant, False)
        check_dist(feature, (curr[0] - 1, curr[1]), quadrant, False)
    elif quadrant == 4:
        check_dist(feature, (curr[0], curr[1] + 1), quadrant, False)
        check_dist(feature, (curr[0] + 1, curr[1]), quadrant, False)
    return 0

# %%
# BLAH - BEST AS OF FRIDAY 6/21/2019 - GL&RA
def solve_quadrant(feature, curr, quadrant, first):
    if(curr[0] < 0 or curr[0] >= dims[0] or curr[1] < 0 or curr[1] >= dims[1]):
        return 0 # OUT OF BOUNDS
    
    #find dist to curr from feature
    d = distance.euclidean(feature, curr)
    if d >= dists[curr] and not first:
        return 1
    dists[curr] = d
    ans[curr[0]][curr[1]] = d * 20
    
    #print(feature)
    if quadrant == 1:
        if len(q) > 0:
            check = q.pop()
            if check == (curr[0] + 1, curr[1]):
                q.append(check)
            else:
                q.append(check)
                q.append((curr[0] + 1, curr[1]))
        else:
            q.append((curr[0] + 1, curr[1]))
        q.append((curr[0], curr[1] - 1))
        
    elif quadrant == 2:
        if len(q) > 0:
            check = q.pop()
            if check == (curr[0] - 1, curr[1]):
                q.append(check)
            else:
                q.append(check)
                q.append((curr[0] - 1, curr[1]))    
        else:
            q.append((curr[0] - 1, curr[1]))
        q.append((curr[0], curr[1] - 1))
        
    elif quadrant == 3:
        if len(q) > 0:
            check = q.pop()
            if check == (curr[0], curr[1] + 1):
                q.append(check)
            else:
                q.append(check)
                q.append((curr[0], curr[1] + 1))
        else:
            q.append((curr[0], curr[1] + 1))
        q.append((curr[0] - 1, curr[1]))
        
    elif quadrant == 4:
        if len(q) > 0:
            check = q.pop()
            if check == (curr[0], curr[1] + 1):
                q.append(check)
            else:
                q.append(check)
                q.append((curr[0], curr[1] + 1))
        else:
            q.append((curr[0], curr[1] + 1))
        q.append((curr[0] + 1, curr[1]))
    return 0

from collections import deque

ans = np.zeros((dims[0], dims[1]))
dists = {}

for r in range(dims[0]):
    for c in range(dims[1]):
        dists[(r,c)] = np.inf

t0 = time()
for feature in idxs:
#     print(f"Time passed: {time() - t0}")
    q = deque()
    q.append(feature)
    first = True
    while len(q) > 0:
        solve_quadrant(feature, q.popleft(), 1, first)
        first = False
    q.append(feature)
    first = True
    while len(q) > 0:
        solve_quadrant(feature, q.popleft(), 3, first)
        first = False
    q.append(feature)
    first = True
    while len(q) > 0:
        if first:
            first = False
            curr = q.popleft()
            solve_quadrant(feature, (curr[0]-1, curr[1]-1), 2, first)
        else:
            solve_quadrant(feature, q.popleft(), 2, first)
    q.append(feature)
    first = True
    while len(q) > 0:
        if first:
            first = False
            curr = q.popleft()
            solve_quadrant(feature, (curr[0]+1, curr[1]+1), 4, first)
        else:
            solve_quadrant(feature, q.popleft(), 4, first)


        
print(f"Total time passed: {time() - t0}")
print("Does the answer match the brute force approach: " + str(np.array_equal(arr, ans)))
matprint(ans)
# Out:
# Total time passed: 9.321913242340088
# Does the answer match the brute force approach: True

# %%
#setting up the dictionary
arr1 = np.zeros((dims[0], dims[1]))
dists = {}
for r in range(dims[0]):
    for c in range(dims[1]):
        dists[(r,c)] = np.inf
t0 = time()
for feature in idxs:
#     print(f"Time passed: {time() - t0}")
    check_dist(feature, feature, 1, True)
    check_dist(feature, feature, 3, True)
    check_dist(feature, (feature[0] - 1, feature[1] - 1), 2, True)
    check_dist(feature, (feature[0] + 1, feature[1] + 1), 4, True)
print(f"Total time passed: {time() - t0}")
matprint(arr1)
# Out:
# Total time passed: 16.669492959976196
# ...

# %%
asdf = '''1080.74  1065.27  1049.95  1034.79   1019.8  1004.99  990.353   975.91  961.665  947.629  933.809  920.217  906.863  893.756  880.909  868.332  856.037  844.038  832.346  820.975  809.938   799.25  788.923  778.974  769.415  760.263  751.532  743.236  735.391  728.011   721.11  714.703  708.802   703.42   698.57  694.262  690.507  687.314   684.69  682.642  681.175  680.294  680  680  680  680.294  681.175  682.642   684.69  687.314  690.507  694.262   698.57   703.42  708.802  714.703   721.11  728.011  735.391  743.236  751.532  760.263  769.415  778.974  
1068.27  1052.62  1037.11  1021.76  1006.58  991.564  976.729  962.081  947.629  933.381  919.348  905.539  891.964  878.635  865.563   852.76  840.238   828.01  816.088  804.487  793.221  782.304  771.751  761.577  751.798  742.428  733.485  724.983  716.938  709.366  702.282  695.701  689.638  684.105  679.117  674.685   670.82  667.533  664.831  662.722  661.211  660.303  660  660  660  660.303  661.211  662.722  664.831  667.533   670.82  674.685  679.117  684.105  689.638  695.701  702.282  709.366  716.938  724.983  733.485  742.428  751.798  761.577  
1056.03  1040.19   1024.5  1008.96  993.579  978.366  963.328  948.472  933.809  919.348  905.097  891.067  877.268  863.713  850.412  837.377  824.621  812.158      800  788.162   776.66  765.506  754.718  744.312  734.302  724.707  715.542  706.824   698.57  690.797   683.52  676.757  670.522  664.831  659.697  655.134  651.153  647.765  644.981  642.806  641.249  640.312  640  640  640  640.312  641.249  642.806  644.981  647.765  651.153  655.134  659.697  664.831  670.522  676.757   683.52  690.797   698.57  706.824  715.542  724.707  734.302  744.312  
1044.03  1028.01  1012.13  996.393  980.816  965.401  950.158  935.094  920.217  905.539  891.067  876.812  862.786  848.999  835.464  822.192  809.197  796.492  784.092   772.01  760.263  748.866  737.835  727.186  716.938  707.107  697.711  688.767  680.294  672.309  664.831  657.875   651.46    645.6  640.312   635.61  631.506  628.013   625.14  622.896  621.289  620.322  620  620  620  620.322  621.289  622.896   625.14  628.013  631.506   635.61  640.312    645.6   651.46  657.875  664.831  672.309  680.294  688.767  697.711  707.107  716.938  727.186  
1032.28  1016.07     1000  984.073  968.297   952.68   937.23  921.954  906.863  891.964  877.268  862.786  848.528  834.506  820.731  807.217  793.977  781.025  768.375  756.042  744.043  732.393   721.11  710.211  699.714  689.638      680   670.82  662.118  653.911   646.22  639.062  632.456  626.418  620.967  616.117  611.882  608.276   605.31  602.993  601.332  600.333  600  600  600  600.333  601.332  602.993   605.31  608.276  611.882  616.117  620.967  626.418  632.456  639.062   646.22  653.911  662.118   670.82      680  689.638  699.714  710.211  
1020.78  1004.39   988.13  972.008  956.033  940.213  924.554  909.065  893.756  878.635  863.713  848.999  834.506  820.244  806.226  792.465  778.974  765.768  752.861   740.27  728.011  716.101  704.557  693.397  682.642  672.309   662.42  652.993   644.05   635.61  627.694  620.322  613.514  607.289  601.664  596.657  592.284  588.558  585.491  583.095  581.378  580.345  580  580  580  580.345  581.378  583.095  585.491  588.558  592.284  596.657  601.664  607.289  613.514  620.322  627.694   635.61   644.05  652.993   662.42  672.309  682.642  693.397  
1009.55  992.975  976.524  960.208  944.034  928.009   912.14  896.437  880.909  865.563  850.412  835.464  820.731  806.226   791.96  777.946  764.199  750.733  737.564  724.707   712.18      700  688.186  676.757  665.733  655.134  644.981  635.295  626.099  617.414  609.262  601.664  594.643  588.218  582.409  577.235  572.713  568.859  565.685  563.205  561.427  560.357  560  560  560  560.357  561.427  563.205  565.685  568.859  572.713  577.235  582.409  588.218  594.643  601.664  609.262  617.414  626.099  635.295  644.981  655.134  665.733  676.757  
998.599  981.835  965.194  948.683  932.309  916.079      900  884.081  868.332   852.76  837.377  822.192  807.217  792.465  777.946  763.675  749.667  735.935  722.496  709.366  696.563  684.105  672.012  660.303  648.999  638.122  627.694  617.738  608.276  599.333  590.931  583.095  575.847   569.21  563.205  557.853  553.173  549.181  545.894  543.323  541.479   540.37  540  540  540   540.37  541.479  543.323  545.894  549.181  553.173  557.853  563.205   569.21  575.847  583.095  590.931  599.333  608.276  617.738  627.694  638.122  648.999  660.303  
987.927  970.979  954.149  937.443  920.869  904.434  888.144  872.009  856.037  840.238  824.621  809.197  793.977  778.974  764.199  749.667  735.391  721.388  707.672  694.262  681.175  668.431  656.049   644.05  632.456  621.289  610.574  600.333  590.593  581.378  572.713  564.624  557.136  550.273  544.059  538.516  533.667  529.528  526.118   523.45  521.536  520.384  520  520  520  520.384  521.536   523.45  526.118  529.528  533.667  538.516  544.059  550.273  557.136  564.624  572.713  581.378  590.593  600.333  610.574  621.289  632.456   644.05  
977.548  960.417  943.398  926.499  909.725  893.085  876.584  860.233  844.038   828.01  812.158  796.492  781.025  765.768  750.733  735.935  721.388  707.107  693.109  679.412  666.033  652.993  640.312  628.013  616.117  604.649  593.633  583.095  573.062   563.56  554.617   546.26  538.516  531.413  524.976   519.23  514.198  509.902   506.36  503.587  501.597    500.4  500  500  500    500.4  501.597  503.587   506.36  509.902  514.198   519.23  524.976  531.413  538.516   546.26  554.617   563.56  573.062  583.095  593.633  604.649  616.117  628.013  
967.471  950.158  932.952   915.86  898.888  882.043  865.332  848.764  832.346  816.088      800  784.092  768.375  752.861  737.564  722.496  707.672  693.109  678.823  664.831  651.153  637.809   624.82  612.209      600  588.218  576.888  566.039  555.698  545.894  536.656  528.015      520   512.64  505.964      500  494.773  490.306  486.621  483.735  481.664  480.416  480  480  480  480.416  481.664  483.735  486.621  490.306  494.773      500  505.964   512.64      520  528.015  536.656  545.894  555.698  566.039  576.888  588.218      600  612.209  
957.706  940.213  922.822  905.539  888.369  871.321    854.4  837.616  820.975  804.487  788.162   772.01  756.042   740.27  724.707  709.366  694.262  679.412  664.831  650.538  636.553  622.896   609.59  596.657  584.123  572.014  560.357  549.181  538.516  528.394  518.845  509.902  501.597  493.964  487.032  480.833  475.395  470.744  466.905  463.897  461.736  460.435  460  460  460  460.435  461.736  463.897  466.905  470.744  475.395  480.833  487.032  493.964  501.597  509.902  518.845  528.394  538.516  549.181  560.357  572.014  584.123  596.657  
948.262  930.591  913.017  895.545   878.18   860.93  843.801  826.801  809.938  793.221   776.66  760.263  744.043  728.011   712.18  696.563  681.175  666.033  651.153  636.553  622.254  608.276  594.643  581.378  568.507  556.058  544.059  532.541  521.536  511.077  501.199  491.935  483.322  475.395  468.188  461.736   456.07  451.221  447.214  444.072  441.814  440.454  440  440  440  440.454  441.814  444.072  447.214  451.221   456.07  461.736  468.188  475.395  483.322  491.935  501.199  511.077  521.536  532.541  544.059  556.058  568.507  581.378  
939.149  921.303  903.549  885.889  868.332  850.882  833.547  816.333   799.25  782.304  765.506  748.866  732.393  716.101      700  684.105  668.431  652.993  637.809  622.896  608.276   593.97      580  566.392  553.173   540.37  528.015   516.14  504.777  493.964  483.735  474.131  465.188  456.946  449.444  442.719  436.807  431.741  427.551  424.264    421.9  420.476  420  420  420  420.476    421.9  424.264  427.551  431.741  436.807  442.719  449.444  456.946  465.188  474.131  483.735  493.964  504.777   516.14  528.015   540.37  553.173  566.392  
930.376   912.36  894.427  876.584  858.836   841.19   823.65  806.226  788.923  771.751  754.718  737.835   721.11  704.557  688.186  672.012  656.049  640.312   624.82   609.59  594.643      580  565.685  551.725  538.145  524.976   512.25      500  488.262  477.074  466.476  456.508  447.214  438.634  430.813  423.792  417.612  412.311  407.922  404.475  401.995    400.5  400  400  400    400.5  401.995  404.475  407.922  412.311  417.612  423.792  430.813  438.634  447.214  456.508  466.476  477.074  488.262      500   512.25  524.976  538.145  551.725  
921.954   903.77  885.664   867.64  849.706  831.865  814.125  796.492  778.974  761.577  744.312  727.186  710.211  693.397  676.757  660.303   644.05  628.013  612.209  596.657  581.378  566.392  551.725  537.401   523.45  509.902   496.79  484.149  472.017  460.435  449.444   439.09  429.418  420.476  412.311  404.969  398.497  392.938   388.33  384.708  382.099  380.526  380  380  380  380.526  382.099  384.708   388.33  392.938  398.497  404.969  412.311  420.476  429.418   439.09  449.444  460.435  472.017  484.149   496.79  509.902   523.45  537.401  
913.893  895.545  877.268  859.069  840.952  822.922  804.984  787.147  769.415  751.798  734.302  716.938  699.714  682.642  665.733  648.999  632.456  616.117      600  584.123  568.507  553.173  538.145   523.45  509.117  495.177  481.664  468.615   456.07  444.072  432.666    421.9  411.825  402.492  393.954  386.264  379.473  373.631  368.782  364.966  362.215  360.555  360  360  360  360.555  362.215  364.966  368.782  373.631  379.473  386.264  393.954  402.492  411.825    421.9  432.666  444.072   456.07  468.615  481.664  495.177  509.117   523.45  
906.201  887.694  869.253  850.882  832.586  814.371  796.241  778.203  760.263  742.428  724.707  707.107  689.638  672.309  655.134  638.122  621.289  604.649  588.218  572.014  556.058   540.37  524.976  509.902  495.177  480.833  466.905  453.431  440.454  428.019  416.173  404.969  394.462  384.708  375.766  367.696  360.555  354.401  349.285  345.254  342.345  340.588  340  340  340  340.588  342.345  345.254  349.285  354.401  360.555  367.696  375.766  384.708  394.462  404.969  416.173  428.019  440.454  453.431  466.905  480.833  495.177  509.902  
898.888  880.227  861.626   843.09  824.621  806.226  787.909  769.675  751.532  733.485  715.542  697.711      680   662.42  644.981  627.694  610.574  593.633  576.888  560.357  544.059  528.015   512.25   496.79  481.664  466.905  452.548  438.634  425.206  412.311      400   388.33  377.359  367.151  357.771  349.285   341.76  335.261  329.848  325.576   322.49  320.624  320  320  320  320.624   322.49  325.576  329.848  335.261   341.76  349.285  357.771  367.151  377.359   388.33      400  412.311  425.206  438.634  452.548  466.905  481.664   496.79  
891.964  873.155    854.4  835.703  817.068  798.499      780  761.577  743.236  724.983  706.824  688.767   670.82  652.993  635.295  617.738  600.333  583.095  566.039  549.181  532.541   516.14      500  484.149  468.615  453.431  438.634  424.264  410.366  396.989  384.187  372.022  360.555  349.857      340  331.059   323.11  316.228  310.483  305.941  302.655  300.666  300  300  300  300.666  302.655  305.941  310.483  316.228   323.11  331.059      340  349.857  360.555  372.022  384.187  396.989  410.366  424.264  438.634  453.431  468.615  484.149  
885.438  866.487  847.585  828.734  809.938  791.202  772.528  753.923  735.391  716.938   698.57  680.294  662.118   644.05  626.099  608.276  590.593  573.062  555.698  538.516  521.536  504.777  488.262  472.017   456.07  440.454  425.206  410.366   395.98  382.099  368.782   356.09  344.093  332.866   322.49   313.05  304.631  297.321  291.204  286.356  282.843  280.713  280  280  280  280.713  282.843  286.356  291.204  297.321  304.631   313.05   322.49  332.866  344.093   356.09  368.782  382.099   395.98  410.366  425.206  440.454   456.07  472.017  
879.318  860.233   841.19  822.192  803.243  784.347  765.506  746.726  728.011  709.366  690.797  672.309  653.911   635.61  617.414  599.333  581.378   563.56  545.894  528.394  511.077  493.964  477.074  460.435  444.072  428.019  412.311  396.989  382.099  367.696  353.836  340.588  328.024  316.228  305.287  295.296  286.356  278.568  272.029  266.833  263.059  260.768  260  260  260  260.768  263.059  266.833  272.029  278.568  286.356  295.296  305.287  316.228  328.024  340.588  353.836  367.696  382.099  396.989  412.311  428.019  444.072  460.435  
873.613    854.4  835.225  816.088  796.994  777.946  758.947      740   721.11  702.282   683.52  664.831   646.22  627.694  609.262  590.931  572.713  554.617  536.656  518.845  501.199  483.735  466.476  449.444  432.666  416.173      400  384.187  368.782  353.836  339.411  325.576   312.41      300  288.444  277.849  268.328      260  252.982  247.386  243.311  240.832  240  240  240  240.832  243.311  247.386  252.982      260  268.328  277.849  288.444      300   312.41  325.576  339.411  353.836  368.782  384.187      400  416.173  432.666  449.444  
868.332  848.999  829.699  810.432  791.202   772.01  752.861  733.757  714.703  695.701  676.757  657.875  639.062  620.322  601.664  583.095  564.624   546.26  528.015  509.902  491.935  474.131  456.508   439.09    421.9  404.969   388.33  372.022   356.09  340.588  325.576  311.127  297.321  284.253  272.029  260.768  250.599  241.661  234.094  228.035  223.607  220.907  220  220  220  220.907  223.607  228.035  234.094  241.661  250.599  260.768  272.029  284.253  297.321  311.127  325.576  340.588   356.09  372.022   388.33  404.969    421.9   439.09  
863.481  844.038  824.621  805.233  785.875  766.551  747.262  728.011  708.802  689.638  670.522   651.46  632.456  613.514  594.643  575.847  557.136  538.516      520  501.597  483.322  465.188  447.214  429.418  411.825  394.462  377.359  360.555  344.093  328.024   312.41  297.321  282.843  269.072  256.125  244.131  233.238  223.607  215.407  208.806  203.961  200.998  200  200  200  200.998  203.961  208.806  215.407  223.607  233.238  244.131  256.125  269.072  282.843  297.321   312.41  328.024  344.093  360.555  377.359  394.462  411.825  429.418  
859.069  839.524      820    800.5  781.025  761.577  742.159  722.772   703.42  684.105  664.831    645.6  626.418  607.289  588.218   569.21  550.273  531.413   512.64  493.964  475.395  456.946  438.634  420.476  402.492  384.708  367.151  349.857  332.866  316.228      300  284.253  269.072  254.558  240.832  228.035  216.333  205.913  196.977  189.737  184.391  181.108  180  180  180  181.108  184.391  189.737  196.977  205.913  216.333  228.035  240.832  254.558  269.072  284.253      300  316.228  332.866  349.857  367.151  384.708  402.492  420.476  
855.102  835.464  815.843  796.241   776.66    757.1  737.564  718.053   698.57  679.117  659.697  640.312  620.967  601.664  582.409  563.205  544.059  524.976  505.964  487.032  468.188  449.444  430.813  412.311  393.954  375.766  357.771      340   322.49  305.287  288.444  272.029  256.125  240.832  226.274  212.603      200   188.68  178.885   170.88  164.924  161.245  160  160  160  161.245  164.924   170.88  178.885   188.68      200  212.603  226.274  240.832  256.125  272.029  288.444  305.287   322.49      340  357.771  375.766  393.954  412.311  
851.587  831.865  812.158  792.465  772.787  753.127  733.485  713.863  694.262  674.685  655.134   635.61  616.117  596.657  577.235  557.853  538.516   519.23      500  480.833  461.736  442.719  423.792  404.969  386.264  367.696  349.285  331.059   313.05  295.296  277.849  260.768  244.131  228.035  212.603   197.99  184.391  172.047  161.245  152.315  145.602  141.421  140  140  140  141.421  145.602  152.315  161.245  172.047  184.391   197.99  212.603  228.035  244.131  260.768  277.849  295.296   313.05  331.059  349.285  367.696  386.264  404.969  
848.528  828.734   808.95  789.177  769.415  749.667  729.932  710.211  690.507   670.82  651.153  631.506  611.882  592.284  572.713  553.173  533.667  514.198  494.773  475.395   456.07  436.807  417.612  398.497  379.473  360.555   341.76   323.11  304.631  286.356  268.328  250.599  233.238  216.333      200  184.391  169.706  156.205  144.222  134.164  126.491  121.655  120  120  120  121.655  126.491  134.164  144.222  156.205  169.706  184.391      200  216.333  233.238  250.599  268.328  286.356  304.631   323.11   341.76  360.555  379.473  398.497  
845.931  826.075  806.226  786.384  766.551  746.726  726.911  707.107  687.314  667.533  647.765  628.013  608.276  588.558  568.859  549.181  529.528  509.902  490.306  470.744  451.221  431.741  412.311  392.938  373.631  354.401  335.261  316.228  297.321  278.568      260  241.661  223.607  205.913   188.68  172.047  156.205  141.421  128.062  116.619  107.703   101.98  100  100  100   101.98  107.703  116.619  128.062  141.421  156.205  172.047   188.68  205.913  223.607  241.661      260  278.568  297.321  316.228  335.261  354.401  373.631  392.938  
843.801  823.893   803.99  784.092  764.199  744.312  724.431  704.557   684.69  664.831  644.981   625.14   605.31  585.491  565.685  545.894  526.118   506.36  486.621  466.905  447.214  427.551  407.922   388.33  368.782  349.285  329.848  310.483  291.204  272.029  252.982  234.094  215.407  196.977  178.885  161.245  144.222  128.062  113.137      100  89.4427  82.4621   80   80   80  82.4621  89.4427      100  113.137  128.062  144.222  161.245  178.885  196.977  215.407  234.094  252.982  272.029  291.204  310.483  329.848  349.285  368.782   388.33  
 842.14  822.192  802.247  782.304  762.365  742.428  722.496  702.567  682.642  662.722  642.806  622.896  602.993  583.095  563.205  543.323   523.45  503.587  483.735  463.897  444.072  424.264  404.475  384.708  364.966  345.254  325.576  305.941  286.356  266.833  247.386  228.035  208.806  189.737   170.88  152.315  134.164  116.619      100  84.8528   72.111  63.2456   60   60   60  63.2456   72.111  84.8528      100  116.619  134.164  152.315   170.88  189.737  208.806  228.035  247.386  266.833  286.356  305.941  325.576  345.254  364.966  384.708  
840.952  820.975  800.999  781.025  761.052   741.08   721.11  701.142  681.175  661.211  641.249  621.289  601.332  581.378  561.427  541.479  521.536  501.597  481.664  461.736  441.814    421.9  401.995  382.099  362.215  342.345   322.49  302.655  282.843  263.059  243.311  223.607  203.961  184.391  164.924  145.602  126.491  107.703  89.4427   72.111  56.5685  44.7214   40   40   40  44.7214  56.5685   72.111  89.4427  107.703  126.491  145.602  164.924  184.391  203.961  223.607  243.311  263.059  282.843  302.655   322.49  342.345  362.215  382.099  
840.238  820.244   800.25  780.256  760.263   740.27  720.278  700.286  680.294  660.303  640.312  620.322  600.333  580.345  560.357   540.37  520.384    500.4  480.416  460.435  440.454  420.476    400.5  380.526  360.555  340.588  320.624  300.666  280.713  260.768  240.832  220.907  200.998  181.108  161.245  141.421  121.655   101.98  82.4621  63.2456  44.7214  28.2843   20   20   20  28.2843  44.7214  63.2456  82.4621   101.98  121.655  141.421  161.245  181.108  200.998  220.907  240.832  260.768  280.713  300.666  320.624  340.588  360.555  380.526  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0   20    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
840.238  820.244   800.25  780.256  760.263   740.27  720.278  700.286  680.294  660.303  640.312  620.322  600.333  580.345  560.357   540.37  520.384    500.4  480.416  460.435  440.454  420.476    400.5  380.526  360.555  340.588  320.624  300.666  280.713  260.768  240.832  220.907  200.998  181.108  161.245  141.421  121.655   101.98  82.4621  63.2456  44.7214  28.2843   20   20   20  28.2843  44.7214  63.2456  82.4621   101.98  121.655  141.421  161.245  181.108  200.998  220.907  240.832  260.768  280.713  300.666  320.624  340.588  360.555  380.526  
840.952  820.975  800.999  781.025  761.052   741.08   721.11  701.142  681.175  661.211  641.249  621.289  601.332  581.378  561.427  541.479  521.536  501.597  481.664  461.736  441.814    421.9  401.995  382.099  362.215  342.345   322.49  302.655  282.843  263.059  243.311  223.607  203.961  184.391  164.924  145.602  126.491  107.703  89.4427   72.111  56.5685  44.7214   40   40   40  44.7214  56.5685   72.111  89.4427  107.703  126.491  145.602  164.924  184.391  203.961  223.607  243.311  263.059  282.843  302.655   322.49  342.345  362.215  382.099  
 842.14  822.192  802.247  782.304  762.365  742.428  722.496  702.567  682.642  662.722  642.806  622.896  602.993  583.095  563.205  543.323   523.45  503.587  483.735  463.897  444.072  424.264  404.475  384.708  364.966  345.254  325.576  305.941  286.356  266.833  247.386  228.035  208.806  189.737   170.88  152.315  134.164  116.619      100  84.8528   72.111  63.2456   60   60   60  63.2456   72.111  84.8528      100  116.619  134.164  152.315   170.88  189.737  208.806  228.035  247.386  266.833  286.356  305.941  325.576  345.254  364.966  384.708  
843.801  823.893   803.99  784.092  764.199  744.312  724.431  704.557   684.69  664.831  644.981   625.14   605.31  585.491  565.685  545.894  526.118   506.36  486.621  466.905  447.214  427.551  407.922   388.33  368.782  349.285  329.848  310.483  291.204  272.029  252.982  234.094  215.407  196.977  178.885  161.245  144.222  128.062  113.137      100  89.4427  82.4621   80   80   80  82.4621  89.4427      100  113.137  128.062  144.222  161.245  178.885  196.977  215.407  234.094  252.982  272.029  291.204  310.483  329.848  349.285  368.782   388.33  
845.931  826.075  806.226  786.384  766.551  746.726  726.911  707.107  687.314  667.533  647.765  628.013  608.276  588.558  568.859  549.181  529.528  509.902  490.306  470.744  451.221  431.741  412.311  392.938  373.631  354.401  335.261  316.228  297.321  278.568      260  241.661  223.607  205.913   188.68  172.047  156.205  141.421  128.062  116.619  107.703   101.98  100  100  100   101.98  107.703  116.619  128.062  141.421  156.205  172.047   188.68  205.913  223.607  241.661      260  278.568  297.321  316.228  335.261  354.401  373.631  392.938  
848.528  828.734   808.95  789.177  769.415  749.667  729.932  710.211  690.507   670.82  651.153  631.506  611.882  592.284  572.713  553.173  533.667  514.198  494.773  475.395   456.07  436.807  417.612  398.497  379.473  360.555   341.76   323.11  304.631  286.356  268.328  250.599  233.238  216.333      200  184.391  169.706  156.205  144.222  134.164  126.491  121.655  120  120  120  121.655  126.491  134.164  144.222  156.205  169.706  184.391      200  216.333  233.238  250.599  268.328  286.356  304.631   323.11   341.76  360.555  379.473  398.497  
851.587  831.865  812.158  792.465  772.787  753.127  733.485  713.863  694.262  674.685  655.134   635.61  616.117  596.657  577.235  557.853  538.516   519.23      500  480.833  461.736  442.719  423.792  404.969  386.264  367.696  349.285  331.059   313.05  295.296  277.849  260.768  244.131  228.035  212.603   197.99  184.391  172.047  161.245  152.315  145.602  141.421  140  140  140  141.421  145.602  152.315  161.245  172.047  184.391   197.99  212.603  228.035  244.131  260.768  277.849  295.296   313.05  331.059  349.285  367.696  386.264  404.969  
855.102  835.464  815.843  796.241   776.66    757.1  737.564  718.053   698.57  679.117  659.697  640.312  620.967  601.664  582.409  563.205  544.059  524.976  505.964  487.032  468.188  449.444  430.813  412.311  393.954  375.766  357.771      340   322.49  305.287  288.444  272.029  256.125  240.832  226.274  212.603      200   188.68  178.885   170.88  164.924  161.245  160  160  160  161.245  164.924   170.88  178.885   188.68      200  212.603  226.274  240.832  256.125  272.029  288.444  305.287   322.49      340  357.771  375.766  393.954  412.311  
859.069  839.524      820    800.5  781.025  761.577  742.159  722.772   703.42  684.105  664.831    645.6  626.418  607.289  588.218   569.21  550.273  531.413   512.64  493.964  475.395  456.946  438.634  420.476  402.492  384.708  367.151  349.857  332.866  316.228      300  284.253  269.072  254.558  240.832  228.035  216.333  205.913  196.977  189.737  184.391  181.108  180  180  180  181.108  184.391  189.737  196.977  205.913  216.333  228.035  240.832  254.558  269.072  284.253      300  316.228  332.866  349.857  367.151  384.708  402.492  420.476  
863.481  844.038  824.621  805.233  785.875  766.551  747.262  728.011  708.802  689.638  670.522   651.46  632.456  613.514  594.643  575.847  557.136  538.516      520  501.597  483.322  465.188  447.214  429.418  411.825  394.462  377.359  360.555  344.093  328.024   312.41  297.321  282.843  269.072  256.125  244.131  233.238  223.607  215.407  208.806  203.961  200.998  200  200  200  200.998  203.961  208.806  215.407  223.607  233.238  244.131  256.125  269.072  282.843  297.321   312.41  328.024  344.093  360.555  377.359  394.462  411.825  429.418  
868.332  848.999  829.699  810.432  791.202   772.01  752.861  733.757  714.703  695.701  676.757  657.875  639.062  620.322  601.664  583.095  564.624   546.26  528.015  509.902  491.935  474.131  456.508   439.09    421.9  404.969   388.33  372.022   356.09  340.588  325.576  311.127  297.321  284.253  272.029  260.768  250.599  241.661  234.094  228.035  223.607  220.907  220  220  220  220.907  223.607  228.035  234.094  241.661  250.599  260.768  272.029  284.253  297.321  311.127  325.576  340.588   356.09  372.022   388.33  404.969    421.9   439.09'''
qwer = '''1080.74  1065.27  1049.95  1034.79   1019.8  1004.99  990.353   975.91  961.665  947.629  933.809  920.217  906.863  893.756  880.909  868.332  856.037  844.038  832.346  820.975  809.938   799.25  788.923  778.974  769.415  760.263  751.532  743.236  735.391  728.011   721.11  714.703  708.802   703.42   698.57  694.262  690.507  687.314   684.69  682.642  681.175  680.294  680  680  680  680.294  681.175  682.642   684.69  687.314  690.507  694.262   698.57   703.42  708.802  714.703   721.11  728.011  735.391  743.236  751.532  760.263  769.415  778.974  
1068.27  1052.62  1037.11  1021.76  1006.58  991.564  976.729  962.081  947.629  933.381  919.348  905.539  891.964  878.635  865.563   852.76  840.238   828.01  816.088  804.487  793.221  782.304  771.751  761.577  751.798  742.428  733.485  724.983  716.938  709.366  702.282  695.701  689.638  684.105  679.117  674.685   670.82  667.533  664.831  662.722  661.211  660.303  660  660  660  660.303  661.211  662.722  664.831  667.533   670.82  674.685  679.117  684.105  689.638  695.701  702.282  709.366  716.938  724.983  733.485  742.428  751.798  761.577  
1056.03  1040.19   1024.5  1008.96  993.579  978.366  963.328  948.472  933.809  919.348  905.097  891.067  877.268  863.713  850.412  837.377  824.621  812.158      800  788.162   776.66  765.506  754.718  744.312  734.302  724.707  715.542  706.824   698.57  690.797   683.52  676.757  670.522  664.831  659.697  655.134  651.153  647.765  644.981  642.806  641.249  640.312  640  640  640  640.312  641.249  642.806  644.981  647.765  651.153  655.134  659.697  664.831  670.522  676.757   683.52  690.797   698.57  706.824  715.542  724.707  734.302  744.312  
1044.03  1028.01  1012.13  996.393  980.816  965.401  950.158  935.094  920.217  905.539  891.067  876.812  862.786  848.999  835.464  822.192  809.197  796.492  784.092   772.01  760.263  748.866  737.835  727.186  716.938  707.107  697.711  688.767  680.294  672.309  664.831  657.875   651.46    645.6  640.312   635.61  631.506  628.013   625.14  622.896  621.289  620.322  620  620  620  620.322  621.289  622.896   625.14  628.013  631.506   635.61  640.312    645.6   651.46  657.875  664.831  672.309  680.294  688.767  697.711  707.107  716.938  727.186  
1032.28  1016.07     1000  984.073  968.297   952.68   937.23  921.954  906.863  891.964  877.268  862.786  848.528  834.506  820.731  807.217  793.977  781.025  768.375  756.042  744.043  732.393   721.11  710.211  699.714  689.638      680   670.82  662.118  653.911   646.22  639.062  632.456  626.418  620.967  616.117  611.882  608.276   605.31  602.993  601.332  600.333  600  600  600  600.333  601.332  602.993   605.31  608.276  611.882  616.117  620.967  626.418  632.456  639.062   646.22  653.911  662.118   670.82      680  689.638  699.714  710.211  
1020.78  1004.39   988.13  972.008  956.033  940.213  924.554  909.065  893.756  878.635  863.713  848.999  834.506  820.244  806.226  792.465  778.974  765.768  752.861   740.27  728.011  716.101  704.557  693.397  682.642  672.309   662.42  652.993   644.05   635.61  627.694  620.322  613.514  607.289  601.664  596.657  592.284  588.558  585.491  583.095  581.378  580.345  580  580  580  580.345  581.378  583.095  585.491  588.558  592.284  596.657  601.664  607.289  613.514  620.322  627.694   635.61   644.05  652.993   662.42  672.309  682.642  693.397  
1009.55  992.975  976.524  960.208  944.034  928.009   912.14  896.437  880.909  865.563  850.412  835.464  820.731  806.226   791.96  777.946  764.199  750.733  737.564  724.707   712.18      700  688.186  676.757  665.733  655.134  644.981  635.295  626.099  617.414  609.262  601.664  594.643  588.218  582.409  577.235  572.713  568.859  565.685  563.205  561.427  560.357  560  560  560  560.357  561.427  563.205  565.685  568.859  572.713  577.235  582.409  588.218  594.643  601.664  609.262  617.414  626.099  635.295  644.981  655.134  665.733  676.757  
998.599  981.835  965.194  948.683  932.309  916.079      900  884.081  868.332   852.76  837.377  822.192  807.217  792.465  777.946  763.675  749.667  735.935  722.496  709.366  696.563  684.105  672.012  660.303  648.999  638.122  627.694  617.738  608.276  599.333  590.931  583.095  575.847   569.21  563.205  557.853  553.173  549.181  545.894  543.323  541.479   540.37  540  540  540   540.37  541.479  543.323  545.894  549.181  553.173  557.853  563.205   569.21  575.847  583.095  590.931  599.333  608.276  617.738  627.694  638.122  648.999  660.303  
987.927  970.979  954.149  937.443  920.869  904.434  888.144  872.009  856.037  840.238  824.621  809.197  793.977  778.974  764.199  749.667  735.391  721.388  707.672  694.262  681.175  668.431  656.049   644.05  632.456  621.289  610.574  600.333  590.593  581.378  572.713  564.624  557.136  550.273  544.059  538.516  533.667  529.528  526.118   523.45  521.536  520.384  520  520  520  520.384  521.536   523.45  526.118  529.528  533.667  538.516  544.059  550.273  557.136  564.624  572.713  581.378  590.593  600.333  610.574  621.289  632.456   644.05  
977.548  960.417  943.398  926.499  909.725  893.085  876.584  860.233  844.038   828.01  812.158  796.492  781.025  765.768  750.733  735.935  721.388  707.107  693.109  679.412  666.033  652.993  640.312  628.013  616.117  604.649  593.633  583.095  573.062   563.56  554.617   546.26  538.516  531.413  524.976   519.23  514.198  509.902   506.36  503.587  501.597    500.4  500  500  500    500.4  501.597  503.587   506.36  509.902  514.198   519.23  524.976  531.413  538.516   546.26  554.617   563.56  573.062  583.095  593.633  604.649  616.117  628.013  
967.471  950.158  932.952   915.86  898.888  882.043  865.332  848.764  832.346  816.088      800  784.092  768.375  752.861  737.564  722.496  707.672  693.109  678.823  664.831  651.153  637.809   624.82  612.209      600  588.218  576.888  566.039  555.698  545.894  536.656  528.015      520   512.64  505.964      500  494.773  490.306  486.621  483.735  481.664  480.416  480  480  480  480.416  481.664  483.735  486.621  490.306  494.773      500  505.964   512.64      520  528.015  536.656  545.894  555.698  566.039  576.888  588.218      600  612.209  
957.706  940.213  922.822  905.539  888.369  871.321    854.4  837.616  820.975  804.487  788.162   772.01  756.042   740.27  724.707  709.366  694.262  679.412  664.831  650.538  636.553  622.896   609.59  596.657  584.123  572.014  560.357  549.181  538.516  528.394  518.845  509.902  501.597  493.964  487.032  480.833  475.395  470.744  466.905  463.897  461.736  460.435  460  460  460  460.435  461.736  463.897  466.905  470.744  475.395  480.833  487.032  493.964  501.597  509.902  518.845  528.394  538.516  549.181  560.357  572.014  584.123  596.657  
948.262  930.591  913.017  895.545   878.18   860.93  843.801  826.801  809.938  793.221   776.66  760.263  744.043  728.011   712.18  696.563  681.175  666.033  651.153  636.553  622.254  608.276  594.643  581.378  568.507  556.058  544.059  532.541  521.536  511.077  501.199  491.935  483.322  475.395  468.188  461.736   456.07  451.221  447.214  444.072  441.814  440.454  440  440  440  440.454  441.814  444.072  447.214  451.221   456.07  461.736  468.188  475.395  483.322  491.935  501.199  511.077  521.536  532.541  544.059  556.058  568.507  581.378  
939.149  921.303  903.549  885.889  868.332  850.882  833.547  816.333   799.25  782.304  765.506  748.866  732.393  716.101      700  684.105  668.431  652.993  637.809  622.896  608.276   593.97      580  566.392  553.173   540.37  528.015   516.14  504.777  493.964  483.735  474.131  465.188  456.946  449.444  442.719  436.807  431.741  427.551  424.264    421.9  420.476  420  420  420  420.476    421.9  424.264  427.551  431.741  436.807  442.719  449.444  456.946  465.188  474.131  483.735  493.964  504.777   516.14  528.015   540.37  553.173  566.392  
930.376   912.36  894.427  876.584  858.836   841.19   823.65  806.226  788.923  771.751  754.718  737.835   721.11  704.557  688.186  672.012  656.049  640.312   624.82   609.59  594.643      580  565.685  551.725  538.145  524.976   512.25      500  488.262  477.074  466.476  456.508  447.214  438.634  430.813  423.792  417.612  412.311  407.922  404.475  401.995    400.5  400  400  400    400.5  401.995  404.475  407.922  412.311  417.612  423.792  430.813  438.634  447.214  456.508  466.476  477.074  488.262      500   512.25  524.976  538.145  551.725  
921.954   903.77  885.664   867.64  849.706  831.865  814.125  796.492  778.974  761.577  744.312  727.186  710.211  693.397  676.757  660.303   644.05  628.013  612.209  596.657  581.378  566.392  551.725  537.401   523.45  509.902   496.79  484.149  472.017  460.435  449.444   439.09  429.418  420.476  412.311  404.969  398.497  392.938   388.33  384.708  382.099  380.526  380  380  380  380.526  382.099  384.708   388.33  392.938  398.497  404.969  412.311  420.476  429.418   439.09  449.444  460.435  472.017  484.149   496.79  509.902   523.45  537.401  
913.893  895.545  877.268  859.069  840.952  822.922  804.984  787.147  769.415  751.798  734.302  716.938  699.714  682.642  665.733  648.999  632.456  616.117      600  584.123  568.507  553.173  538.145   523.45  509.117  495.177  481.664  468.615   456.07  444.072  432.666    421.9  411.825  402.492  393.954  386.264  379.473  373.631  368.782  364.966  362.215  360.555  360  360  360  360.555  362.215  364.966  368.782  373.631  379.473  386.264  393.954  402.492  411.825    421.9  432.666  444.072   456.07  468.615  481.664  495.177  509.117   523.45  
906.201  887.694  869.253  850.882  832.586  814.371  796.241  778.203  760.263  742.428  724.707  707.107  689.638  672.309  655.134  638.122  621.289  604.649  588.218  572.014  556.058   540.37  524.976  509.902  495.177  480.833  466.905  453.431  440.454  428.019  416.173  404.969  394.462  384.708  375.766  367.696  360.555  354.401  349.285  345.254  342.345  340.588  340  340  340  340.588  342.345  345.254  349.285  354.401  360.555  367.696  375.766  384.708  394.462  404.969  416.173  428.019  440.454  453.431  466.905  480.833  495.177  509.902  
898.888  880.227  861.626   843.09  824.621  806.226  787.909  769.675  751.532  733.485  715.542  697.711      680   662.42  644.981  627.694  610.574  593.633  576.888  560.357  544.059  528.015   512.25   496.79  481.664  466.905  452.548  438.634  425.206  412.311      400   388.33  377.359  367.151  357.771  349.285   341.76  335.261  329.848  325.576   322.49  320.624  320  320  320  320.624   322.49  325.576  329.848  335.261   341.76  349.285  357.771  367.151  377.359   388.33      400  412.311  425.206  438.634  452.548  466.905  481.664   496.79  
891.964  873.155    854.4  835.703  817.068  798.499      780  761.577  743.236  724.983  706.824  688.767   670.82  652.993  635.295  617.738  600.333  583.095  566.039  549.181  532.541   516.14      500  484.149  468.615  453.431  438.634  424.264  410.366  396.989  384.187  372.022  360.555  349.857      340  331.059   323.11  316.228  310.483  305.941  302.655  300.666  300  300  300  300.666  302.655  305.941  310.483  316.228   323.11  331.059      340  349.857  360.555  372.022  384.187  396.989  410.366  424.264  438.634  453.431  468.615  484.149  
885.438  866.487  847.585  828.734  809.938  791.202  772.528  753.923  735.391  716.938   698.57  680.294  662.118   644.05  626.099  608.276  590.593  573.062  555.698  538.516  521.536  504.777  488.262  472.017   456.07  440.454  425.206  410.366   395.98  382.099  368.782   356.09  344.093  332.866   322.49   313.05  304.631  297.321  291.204  286.356  282.843  280.713  280  280  280  280.713  282.843  286.356  291.204  297.321  304.631   313.05   322.49  332.866  344.093   356.09  368.782  382.099   395.98  410.366  425.206  440.454   456.07  472.017  
879.318  860.233   841.19  822.192  803.243  784.347  765.506  746.726  728.011  709.366  690.797  672.309  653.911   635.61  617.414  599.333  581.378   563.56  545.894  528.394  511.077  493.964  477.074  460.435  444.072  428.019  412.311  396.989  382.099  367.696  353.836  340.588  328.024  316.228  305.287  295.296  286.356  278.568  272.029  266.833  263.059  260.768  260  260  260  260.768  263.059  266.833  272.029  278.568  286.356  295.296  305.287  316.228  328.024  340.588  353.836  367.696  382.099  396.989  412.311  428.019  444.072  460.435  
873.613    854.4  835.225  816.088  796.994  777.946  758.947      740   721.11  702.282   683.52  664.831   646.22  627.694  609.262  590.931  572.713  554.617  536.656  518.845  501.199  483.735  466.476  449.444  432.666  416.173      400  384.187  368.782  353.836  339.411  325.576   312.41      300  288.444  277.849  268.328      260  252.982  247.386  243.311  240.832  240  240  240  240.832  243.311  247.386  252.982      260  268.328  277.849  288.444      300   312.41  325.576  339.411  353.836  368.782  384.187      400  416.173  432.666  449.444  
868.332  848.999  829.699  810.432  791.202   772.01  752.861  733.757  714.703  695.701  676.757  657.875  639.062  620.322  601.664  583.095  564.624   546.26  528.015  509.902  491.935  474.131  456.508   439.09    421.9  404.969   388.33  372.022   356.09  340.588  325.576  311.127  297.321  284.253  272.029  260.768  250.599  241.661  234.094  228.035  223.607  220.907  220  220  220  220.907  223.607  228.035  234.094  241.661  250.599  260.768  272.029  284.253  297.321  311.127  325.576  340.588   356.09  372.022   388.33  404.969    421.9   439.09  
863.481  844.038  824.621  805.233  785.875  766.551  747.262  728.011  708.802  689.638  670.522   651.46  632.456  613.514  594.643  575.847  557.136  538.516      520  501.597  483.322  465.188  447.214  429.418  411.825  394.462  377.359  360.555  344.093  328.024   312.41  297.321  282.843  269.072  256.125  244.131  233.238  223.607  215.407  208.806  203.961  200.998  200  200  200  200.998  203.961  208.806  215.407  223.607  233.238  244.131  256.125  269.072  282.843  297.321   312.41  328.024  344.093  360.555  377.359  394.462  411.825  429.418  
859.069  839.524      820    800.5  781.025  761.577  742.159  722.772   703.42  684.105  664.831    645.6  626.418  607.289  588.218   569.21  550.273  531.413   512.64  493.964  475.395  456.946  438.634  420.476  402.492  384.708  367.151  349.857  332.866  316.228      300  284.253  269.072  254.558  240.832  228.035  216.333  205.913  196.977  189.737  184.391  181.108  180  180  180  181.108  184.391  189.737  196.977  205.913  216.333  228.035  240.832  254.558  269.072  284.253      300  316.228  332.866  349.857  367.151  384.708  402.492  420.476  
855.102  835.464  815.843  796.241   776.66    757.1  737.564  718.053   698.57  679.117  659.697  640.312  620.967  601.664  582.409  563.205  544.059  524.976  505.964  487.032  468.188  449.444  430.813  412.311  393.954  375.766  357.771      340   322.49  305.287  288.444  272.029  256.125  240.832  226.274  212.603      200   188.68  178.885   170.88  164.924  161.245  160  160  160  161.245  164.924   170.88  178.885   188.68      200  212.603  226.274  240.832  256.125  272.029  288.444  305.287   322.49      340  357.771  375.766  393.954  412.311  
851.587  831.865  812.158  792.465  772.787  753.127  733.485  713.863  694.262  674.685  655.134   635.61  616.117  596.657  577.235  557.853  538.516   519.23      500  480.833  461.736  442.719  423.792  404.969  386.264  367.696  349.285  331.059   313.05  295.296  277.849  260.768  244.131  228.035  212.603   197.99  184.391  172.047  161.245  152.315  145.602  141.421  140  140  140  141.421  145.602  152.315  161.245  172.047  184.391   197.99  212.603  228.035  244.131  260.768  277.849  295.296   313.05  331.059  349.285  367.696  386.264  404.969  
848.528  828.734   808.95  789.177  769.415  749.667  729.932  710.211  690.507   670.82  651.153  631.506  611.882  592.284  572.713  553.173  533.667  514.198  494.773  475.395   456.07  436.807  417.612  398.497  379.473  360.555   341.76   323.11  304.631  286.356  268.328  250.599  233.238  216.333      200  184.391  169.706  156.205  144.222  134.164  126.491  121.655  120  120  120  121.655  126.491  134.164  144.222  156.205  169.706  184.391      200  216.333  233.238  250.599  268.328  286.356  304.631   323.11   341.76  360.555  379.473  398.497  
845.931  826.075  806.226  786.384  766.551  746.726  726.911  707.107  687.314  667.533  647.765  628.013  608.276  588.558  568.859  549.181  529.528  509.902  490.306  470.744  451.221  431.741  412.311  392.938  373.631  354.401  335.261  316.228  297.321  278.568      260  241.661  223.607  205.913   188.68  172.047  156.205  141.421  128.062  116.619  107.703   101.98  100  100  100   101.98  107.703  116.619  128.062  141.421  156.205  172.047   188.68  205.913  223.607  241.661      260  278.568  297.321  316.228  335.261  354.401  373.631  392.938  
843.801  823.893   803.99  784.092  764.199  744.312  724.431  704.557   684.69  664.831  644.981   625.14   605.31  585.491  565.685  545.894  526.118   506.36  486.621  466.905  447.214  427.551  407.922   388.33  368.782  349.285  329.848  310.483  291.204  272.029  252.982  234.094  215.407  196.977  178.885  161.245  144.222  128.062  113.137      100  89.4427  82.4621   80   80   80  82.4621  89.4427      100  113.137  128.062  144.222  161.245  178.885  196.977  215.407  234.094  252.982  272.029  291.204  310.483  329.848  349.285  368.782   388.33  
 842.14  822.192  802.247  782.304  762.365  742.428  722.496  702.567  682.642  662.722  642.806  622.896  602.993  583.095  563.205  543.323   523.45  503.587  483.735  463.897  444.072  424.264  404.475  384.708  364.966  345.254  325.576  305.941  286.356  266.833  247.386  228.035  208.806  189.737   170.88  152.315  134.164  116.619      100  84.8528   72.111  63.2456   60   60   60  63.2456   72.111  84.8528      100  116.619  134.164  152.315   170.88  189.737  208.806  228.035  247.386  266.833  286.356  305.941  325.576  345.254  364.966  384.708  
840.952  820.975  800.999  781.025  761.052   741.08   721.11  701.142  681.175  661.211  641.249  621.289  601.332  581.378  561.427  541.479  521.536  501.597  481.664  461.736  441.814    421.9  401.995  382.099  362.215  342.345   322.49  302.655  282.843  263.059  243.311  223.607  203.961  184.391  164.924  145.602  126.491  107.703  89.4427   72.111  56.5685  44.7214   40   40   40  44.7214  56.5685   72.111  89.4427  107.703  126.491  145.602  164.924  184.391  203.961  223.607  243.311  263.059  282.843  302.655   322.49  342.345  362.215  382.099  
840.238  820.244   800.25  780.256  760.263   740.27  720.278  700.286  680.294  660.303  640.312  620.322  600.333  580.345  560.357   540.37  520.384    500.4  480.416  460.435  440.454  420.476    400.5  380.526  360.555  340.588  320.624  300.666  280.713  260.768  240.832  220.907  200.998  181.108  161.245  141.421  121.655   101.98  82.4621  63.2456  44.7214  28.2843   20   20   20  28.2843  44.7214  63.2456  82.4621   101.98  121.655  141.421  161.245  181.108  200.998  220.907  240.832  260.768  280.713  300.666  320.624  340.588  360.555  380.526  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0   20    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
    840      820      800      780      760      740      720      700      680      660      640      620      600      580      560      540      520      500      480      460      440      420      400      380      360      340      320      300      280      260      240      220      200      180      160      140      120      100       80       60       40       20    0    0    0       20       40       60       80      100      120      140      160      180      200      220      240      260      280      300      320      340      360      380  
840.238  820.244   800.25  780.256  760.263   740.27  720.278  700.286  680.294  660.303  640.312  620.322  600.333  580.345  560.357   540.37  520.384    500.4  480.416  460.435  440.454  420.476    400.5  380.526  360.555  340.588  320.624  300.666  280.713  260.768  240.832  220.907  200.998  181.108  161.245  141.421  121.655   101.98  82.4621  63.2456  44.7214  28.2843   20   20   20  28.2843  44.7214  63.2456  82.4621   101.98  121.655  141.421  161.245  181.108  200.998  220.907  240.832  260.768  280.713  300.666  320.624  340.588  360.555  380.526  
840.952  820.975  800.999  781.025  761.052   741.08   721.11  701.142  681.175  661.211  641.249  621.289  601.332  581.378  561.427  541.479  521.536  501.597  481.664  461.736  441.814    421.9  401.995  382.099  362.215  342.345   322.49  302.655  282.843  263.059  243.311  223.607  203.961  184.391  164.924  145.602  126.491  107.703  89.4427   72.111  56.5685  44.7214   40   40   40  44.7214  56.5685   72.111  89.4427  107.703  126.491  145.602  164.924  184.391  203.961  223.607  243.311  263.059  282.843  302.655   322.49  342.345  362.215  382.099  
 842.14  822.192  802.247  782.304  762.365  742.428  722.496  702.567  682.642  662.722  642.806  622.896  602.993  583.095  563.205  543.323   523.45  503.587  483.735  463.897  444.072  424.264  404.475  384.708  364.966  345.254  325.576  305.941  286.356  266.833  247.386  228.035  208.806  189.737   170.88  152.315  134.164  116.619      100  84.8528   72.111  63.2456   60   60   60  63.2456   72.111  84.8528      100  116.619  134.164  152.315   170.88  189.737  208.806  228.035  247.386  266.833  286.356  305.941  325.576  345.254  364.966  384.708  
843.801  823.893   803.99  784.092  764.199  744.312  724.431  704.557   684.69  664.831  644.981   625.14   605.31  585.491  565.685  545.894  526.118   506.36  486.621  466.905  447.214  427.551  407.922   388.33  368.782  349.285  329.848  310.483  291.204  272.029  252.982  234.094  215.407  196.977  178.885  161.245  144.222  128.062  113.137      100  89.4427  82.4621   80   80   80  82.4621  89.4427      100  113.137  128.062  144.222  161.245  178.885  196.977  215.407  234.094  252.982  272.029  291.204  310.483  329.848  349.285  368.782   388.33  
845.931  826.075  806.226  786.384  766.551  746.726  726.911  707.107  687.314  667.533  647.765  628.013  608.276  588.558  568.859  549.181  529.528  509.902  490.306  470.744  451.221  431.741  412.311  392.938  373.631  354.401  335.261  316.228  297.321  278.568      260  241.661  223.607  205.913   188.68  172.047  156.205  141.421  128.062  116.619  107.703   101.98  100  100  100   101.98  107.703  116.619  128.062  141.421  156.205  172.047   188.68  205.913  223.607  241.661      260  278.568  297.321  316.228  335.261  354.401  373.631  392.938  
848.528  828.734   808.95  789.177  769.415  749.667  729.932  710.211  690.507   670.82  651.153  631.506  611.882  592.284  572.713  553.173  533.667  514.198  494.773  475.395   456.07  436.807  417.612  398.497  379.473  360.555   341.76   323.11  304.631  286.356  268.328  250.599  233.238  216.333      200  184.391  169.706  156.205  144.222  134.164  126.491  121.655  120  120  120  121.655  126.491  134.164  144.222  156.205  169.706  184.391      200  216.333  233.238  250.599  268.328  286.356  304.631   323.11   341.76  360.555  379.473  398.497  
851.587  831.865  812.158  792.465  772.787  753.127  733.485  713.863  694.262  674.685  655.134   635.61  616.117  596.657  577.235  557.853  538.516   519.23      500  480.833  461.736  442.719  423.792  404.969  386.264  367.696  349.285  331.059   313.05  295.296  277.849  260.768  244.131  228.035  212.603   197.99  184.391  172.047  161.245  152.315  145.602  141.421  140  140  140  141.421  145.602  152.315  161.245  172.047  184.391   197.99  212.603  228.035  244.131  260.768  277.849  295.296   313.05  331.059  349.285  367.696  386.264  404.969  
855.102  835.464  815.843  796.241   776.66    757.1  737.564  718.053   698.57  679.117  659.697  640.312  620.967  601.664  582.409  563.205  544.059  524.976  505.964  487.032  468.188  449.444  430.813  412.311  393.954  375.766  357.771      340   322.49  305.287  288.444  272.029  256.125  240.832  226.274  212.603      200   188.68  178.885   170.88  164.924  161.245  160  160  160  161.245  164.924   170.88  178.885   188.68      200  212.603  226.274  240.832  256.125  272.029  288.444  305.287   322.49      340  357.771  375.766  393.954  412.311  
859.069  839.524      820    800.5  781.025  761.577  742.159  722.772   703.42  684.105  664.831    645.6  626.418  607.289  588.218   569.21  550.273  531.413   512.64  493.964  475.395  456.946  438.634  420.476  402.492  384.708  367.151  349.857  332.866  316.228      300  284.253  269.072  254.558  240.832  228.035  216.333  205.913  196.977  189.737  184.391  181.108  180  180  180  181.108  184.391  189.737  196.977  205.913  216.333  228.035  240.832  254.558  269.072  284.253      300  316.228  332.866  349.857  367.151  384.708  402.492  420.476  
863.481  844.038  824.621  805.233  785.875  766.551  747.262  728.011  708.802  689.638  670.522   651.46  632.456  613.514  594.643  575.847  557.136  538.516      520  501.597  483.322  465.188  447.214  429.418  411.825  394.462  377.359  360.555  344.093  328.024   312.41  297.321  282.843  269.072  256.125  244.131  233.238  223.607  215.407  208.806  203.961  200.998  200  200  200  200.998  203.961  208.806  215.407  223.607  233.238  244.131  256.125  269.072  282.843  297.321   312.41  328.024  344.093  360.555  377.359  394.462  411.825  429.418  
868.332  848.999  829.699  810.432  791.202   772.01  752.861  733.757  714.703  695.701  676.757  657.875  639.062  620.322  601.664  583.095  564.624   546.26  528.015  509.902  491.935  474.131  456.508   439.09    421.9  404.969   388.33  372.022   356.09  340.588  325.576  311.127  297.321  284.253  272.029  260.768  250.599  241.661  234.094  228.035  223.607  220.907  220  220  220  220.907  223.607  228.035  234.094  241.661  250.599  260.768  272.029  284.253  297.321  311.127  325.576  340.588   356.09  372.022   388.33  404.969    421.9   439.09'''

# %%
print(asdf==qwer)
# Out:
# True

# %%
i = np.ones((2,2))
i[0,1] = 15
i
# Out:
# array([[ 1., 15.],
#        [ 1.,  1.]])
